# %% [markdown]
# <a href="https://colab.research.google.com/github/yoyoyo-yo/DeepLearningMugenKnock/blob/master/pytorch/ResNeXt50_CIFAR100_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ResNeXt, CIFAR100

# %%
# !pip install numpy matplotlib opencv-python torch torchvision torchsummary pandas easydict

# %% [markdown]
# # Import and Config

# %%
import os
from pprint import pprint
import argparse

import numpy as np
from collections import OrderedDict
from easydict import EasyDict
import matplotlib.pyplot as plt
import pandas as pd
import cv2
import seaborn as sns

import torch
import torch.nn.functional as F
import torchvision
from torchsummary import summary

#---
# config
#---
cfg = EasyDict()

# class
cfg.CLASS_LABEL = range(100) # list, dict('label' : '[B, G, R]')
cfg.CLASS_NUM = len(cfg.CLASS_LABEL)

# model
cfg.INPUT_HEIGHT = 32
cfg.INPUT_WIDTH = 32
cfg.INPUT_CHANNEL = 3
cfg.INPUT_MODE = 'RGB' #RGB, GRAY, CLASS_LABEL, EDGE

cfg.CHANNEL_AXIS = 1 # 1 ... [mb, c, h, w], 3 ... [mb, h, w, c]

cfg.GPU = True
cfg.DEVICE_TYPE = 'cuda' if cfg.GPU and torch.cuda.is_available() else 'cpu'
cfg.DEVICE = torch.device(cfg.DEVICE_TYPE)


# train
cfg.TRAIN = EasyDict()
cfg.TRAIN.DISPAY_ITERATION_INTERVAL = 50

cfg.PREFIX = 'ResNeXt50'
cfg.TRAIN.MODEL_SAVE_PATH = 'models/' + cfg.PREFIX + '_{}.pt'
cfg.TRAIN.MODEL_SAVE_INTERVAL = 200
cfg.TRAIN.ITERATION = 20_000
#cfg.TRAIN.EPOCH = 2
cfg.TRAIN.MINIBATCH = 64
cfg.TRAIN.OPTIMIZER = torch.optim.SGD
cfg.TRAIN.LEARNING_PARAMS = {'lr' : 0.001, 'momentum' : 0.9} #{'lr' : 0.02, 'betas' : (0.5, 0.9)}
cfg.TRAIN.LOSS_FUNCTION = loss_fn = torch.nn.CrossEntropyLoss()

cfg.TRAIN.DATA_PATH = './data/' # 'drive/My Drive/Colab Notebooks/Dataset/train/images/'
cfg.TRAIN.DATA_HORIZONTAL_FLIP = False
cfg.TRAIN.DATA_VERTICAL_FLIP = False
cfg.TRAIN.DATA_ROTATION = False

cfg.TRAIN.LEARNING_PROCESS_RESULT_SAVE = True
cfg.TRAIN.LEARNING_PROCESS_RESULT_INTERVAL = 500
cfg.TRAIN.LEARNING_PROCESS_RESULT_IMAGE_PATH = 'result/' + cfg.PREFIX + '_result_{}.jpg'
cfg.TRAIN.LEARNING_PROCESS_RESULT_LOSS_PATH = 'result/' + cfg.PREFIX + '_loss.csv'

# test
cfg.TEST = EasyDict()
cfg.TEST.MODEL_PATH = cfg.TRAIN.MODEL_SAVE_PATH.format('final')
cfg.TEST.DATA_PATH = './data/' # 'drive/My Drive/Colab Notebooks/Dataset/test/images/
cfg.TEST.MINIBATCH = 100
cfg.TEST.ITERATION = 2
cfg.TEST.MAX_NUM = 100
cfg.TEST.RESULT_SAVE = False
cfg.TEST.RESULT_IMAGE_PATH = 'result/' + cfg.PREFIX + '_result_{}.jpg'

# random seed
torch.manual_seed(0)


# make model save directory
def make_dir(path):
    if '/' in path:
        model_save_dir = '/'.join(path.split('/')[:-1])
        os.makedirs(model_save_dir, exist_ok=True)

make_dir(cfg.TRAIN.MODEL_SAVE_PATH)
make_dir(cfg.TRAIN.LEARNING_PROCESS_RESULT_IMAGE_PATH)
make_dir(cfg.TRAIN.LEARNING_PROCESS_RESULT_LOSS_PATH)
    
pprint(cfg)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# {'CHANNEL_AXIS': 1,
#  'CLASS_LABEL': range(0, 100),
#  'CLASS_NUM': 100,
#  'DEVICE': device(type='cuda'),
#  'DEVICE_TYPE': 'cuda',
#  'GPU': True,
#  'INPUT_CHANNEL': 3,
#  'INPUT_HEIGHT': 32,
#  'INPUT_MODE': 'RGB',
#  'INPUT_WIDTH': 32,
#  'PREFIX': 'ResNeXt50',
#  'TEST': {'DATA_PATH': './data/',
#           'ITERATION': 2,
#           'MAX_NUM': 100,
#           'MINIBATCH': 100,
#           'MODEL_PATH': 'models/ResNeXt50_final.pt',
#           'RESULT_IMAGE_PATH': 'result/ResNeXt50_result_{}.jpg',
#           'RESULT_SAVE': False},
#  'TRAIN': {'DATA_HORIZONTAL_FLIP': False,
#            'DATA_PATH': './data/',
#            'DATA_ROTATION': False,
#            'DATA_VERTICAL_FLIP': False,
#            'DISPAY_ITERATION_INTERVAL': 50,
#            'ITERATION': 20000,
#            'LEARNING_PARAMS': {'lr': 0.001, 'momentum': 0.9},
#            'LEARNING_PROCESS_RESULT_IMAGE_PATH': 'result/ResNeXt50_result_{}.jpg',
#            'LEARNING_PROCESS_RESULT_INTERVAL': 500,
#            'LEARNING_PROCESS_RESULT_LOSS_PATH': 'result/ResNeXt50_loss.csv',
#            'LEARNING_PROCESS_RESULT_SAVE': True,
#            'LOSS_FUNCTION': CrossEntropyLoss(),
#            'MINIBATCH': 64,
#            'MODEL_SAVE_INTERVAL': 200,
#            'MODEL_SAVE_PATH': 'models/ResNeXt50_{}.pt',
#            'OPTIMIZER': <class 'torch.optim.sgd.SGD'>}}

# %% [markdown]
# # Define Model

# %%
class ResNeXt50(torch.nn.Module):
    def __init__(self):
        super(ResNeXt50, self).__init__()

        class ResNeXtBlock(torch.nn.Module):
            def __init__(self, in_f, f_1, out_f, stride=1, cardinality=32):
                super(ResNeXtBlock, self).__init__()

                self.stride = stride
                self.fit_dim = False
                
                self.block = torch.nn.Sequential(
                    torch.nn.Conv2d(in_f, f_1, kernel_size=1, padding=0, stride=stride),
                    torch.nn.BatchNorm2d(f_1),
                    torch.nn.ReLU(),
                    torch.nn.Conv2d(f_1, f_1, kernel_size=3, padding=1, stride=1, groups=cardinality),
                    torch.nn.BatchNorm2d(f_1),
                    torch.nn.ReLU(),
                    torch.nn.Conv2d(f_1, out_f, kernel_size=1, padding=0, stride=1),
                    torch.nn.BatchNorm2d(out_f),
                    torch.nn.ReLU(),
                )

                if in_f != out_f:
                    self.fit_conv = torch.nn.Conv2d(in_f, out_f, kernel_size=1, padding=0, stride=1)
                    self.fit_dim = True
            
            def forward(self, x):
                res_x = self.block(x)
                
                if self.fit_dim:
                    x = self.fit_conv(x)
                
                if self.stride == 2:
                    x = F.max_pool2d(x, 2, stride=2)
                    
                x = torch.add(res_x, x)
                x = F.relu(x)
                return x

        self.conv1 = torch.nn.Conv2d(cfg.INPUT_CHANNEL, 64, kernel_size=7, padding=3, stride=2)
        self.bn1 = torch.nn.BatchNorm2d(64)
        
        
        self.block2_1 = ResNeXtBlock(64, 64, 256)
        self.block2_2 = ResNeXtBlock(256, 64, 256)
        self.block2_3 = ResNeXtBlock(256, 64, 256)

        self.block3_1 = ResNeXtBlock(256, 128, 512, stride=2)
        self.block3_2 = ResNeXtBlock(512, 128, 512)
        self.block3_3 = ResNeXtBlock(512, 128, 512)
        self.block3_4 = ResNeXtBlock(512, 128, 512)

        self.block4_1 = ResNeXtBlock(512, 256, 1024, stride=2)
        self.block4_2 = ResNeXtBlock(1024, 256, 1024)
        self.block4_3 = ResNeXtBlock(1024, 256, 1024)
        self.block4_4 = ResNeXtBlock(1024, 256, 1024)
        self.block4_5 = ResNeXtBlock(1024, 256, 1024)
        self.block4_6 = ResNeXtBlock(1024, 256, 1024)

        self.block5_1 = ResNeXtBlock(1024, 512, 2048, stride=2)
        self.block5_2 = ResNeXtBlock(2048, 512, 2048)
        self.block5_3 = ResNeXtBlock(2048, 512, 2048)
        
        self.linear = torch.nn.Linear(2048, cfg.CLASS_NUM)
        
        
    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 3, padding=1, stride=2)

        x = self.block2_1(x)
        x = self.block2_2(x)
        x = self.block2_3(x)

        x = self.block3_1(x)
        x = self.block3_2(x)
        x = self.block3_3(x)
        x = self.block3_4(x)

        x = self.block4_1(x)
        x = self.block4_2(x)
        x = self.block4_3(x)
        x = self.block4_4(x)
        x = self.block4_5(x)
        x = self.block4_6(x)

        x = self.block5_1(x)
        x = self.block5_2(x)
        x = self.block5_3(x)

        x = F.avg_pool2d(x, [cfg.INPUT_HEIGHT // 32, cfg.INPUT_WIDTH // 32], padding=0, stride=1)
        x = x.view(x.size()[0], -1)
        x = self.linear(x)
        #x = F.softmax(x, dim=1)
        return x

# %% [markdown]
# # Utility

# %%
class BatchGenerator():
    def __init__(self, data_size, batch_size, shuffle=True):
        self.data_size = data_size
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.mbi = 0 # index for iteration
        self.inds = np.arange(data_size)
        if shuffle:
            np.random.shuffle(self.inds)

    def __call__(self):
        if self.mbi + self.batch_size > self.data_size:
            inds = self.inds[self.mbi:]
            if self.shuffle:
                np.random.shuffle(self.inds)

            inds = np.hstack((inds, self.inds[ : (self.batch_size - (self.data_size - self.mbi))]))
            self.mbi = self.batch_size - (self.data_size - self.mbi)
        else:
            inds = self.inds[self.mbi : self.mbi + self.batch_size]
            self.mbi += self.batch_size
        return inds


#---
# preprocess for torchvision.datasets
#---
def preprocess(Xs, cfg, mode, hf=False, vf=False, rot=False):
    xs = []

    for x in Xs:
        # resize
        x = cv2.resize(x, (cfg.INPUT_WIDTH, cfg.INPUT_HEIGHT)).astype(np.float32)
        
        # channel BGR -> Gray
        if mode == 'GRAY':
            x = cv2.cvtColor(x, cv2.COLOR_BGR2GRAY)
            x = np.expand_dims(x, axis=-1)
        elif mode == 'EDGE':
            x = cv2.cvtColor(x, cv2.COLOR_BGR2GRAY)
            x = cv2.Canny(x, 100, 150)
            x = np.expand_dims(x, axis=-1)

        # horizontal flip
        if hf and np.random.rand() < 0.5:
            x = x[:, ::-1]

        # vertical flip
        if vf and np.random.rand() < 0.5:
            x = x[::-1]

        # rotation
        if rot != False:
            rot = np.random.randint(0, 360, 1) // rot * rot

            scale = 1

            _h, _w = x.shape[:2]
            _c = 1
            if len(x.shape) == 3:
                _c = x.shape[2]

            max_side = max(_h, _w)
            tmp = np.zeros((max_side, max_side, _c))
            tx = int((max_side - _w) / 2)
            ty = int((max_side - _h) / 2)
            tmp[ty: ty+_h, tx: tx+_w] = x.copy()
            M = cv2.getRotationMatrix2D((max_side / 2, max_side / 2), rot, scale)
            _x = cv2.warpAffine(tmp, M, (max_side, max_side))
            x = _x[tx:tx+_w, ty:ty+_h]

        if mode == 'CLASS_LABEL':
            _x = x
            x = np.zeros((cfg.OUTPUT_HEIGHT, cfg.OUTPUT_WIDTH, cfg.CLASS_NUM), dtype=np.int)

            for i, (_, vs) in enumerate(cfg.CLASS_LABEL.items()):
                ind = (_x[..., 0] == vs[0]) * (_x[..., 1] == vs[1]) * (_x[..., 2] == vs[2])
                x[..., i][ind] = 1

        else:
            # normalization [0, 255] -> [-1, 1]
            x = x / 127.5 - 1

        xs.append(x)
                
    xs = np.array(xs, dtype=np.float32)
    if cfg.CHANNEL_AXIS == 1:
        if len(xs.shape) == 4:
            xs = xs.transpose(0, 3, 1, 2)
        else:
            xs = np.expand_dims(xs, axis=1)
    else:
        if len(xs.shape) == 3:
            xs = np.expand_dims(xs, axis=-1)

    return xs

# %% [markdown]
# # Train

# %%
def train():
    # model
    model = ResNeXt50().to(cfg.DEVICE)
    model.train()
    
    summary(model, (cfg.INPUT_CHANNEL, cfg.INPUT_HEIGHT, cfg.INPUT_WIDTH))
    opt = cfg.TRAIN.OPTIMIZER(model.parameters(), **cfg.TRAIN.LEARNING_PARAMS)

    #path_dict = data_load(cfg)
    #paths = path_dict['paths']
    #paths_gt = path_dict['paths_gt']

    ds = torchvision.datasets.CIFAR100(root=cfg.TRAIN.DATA_PATH , train=True, download=True, transform=None)
    Xs_data = torch.tensor(ds.data, dtype=torch.float).permute(0, 3, 1, 2).to(cfg.DEVICE)
    Xs_data = Xs_data / 127.5 - 1
    ts_data = torch.tensor(ds.targets, dtype=torch.long).to(cfg.DEVICE)
    data_num = len(Xs_data)
    #train_ts = np.identity(cfg.CLASS_NUM)[trainset.targets] # one hot

    # training
    batch_gen = BatchGenerator(data_num, cfg.TRAIN.MINIBATCH)

    list_iter = []
    list_loss= []
    list_accuracy = []

    print('training start')
    progres_bar = ''
    
    for i in range(cfg.TRAIN.ITERATION):
        # sample X and t
        mb_inds = batch_gen()
        #Xs = torch.tensor(preprocess(Xs_data[mb_inds], cfg, cfg.INPUT_MODE), dtype=torch.float).to(cfg.DEVICE)
        Xs = Xs_data[mb_inds]
        ts = ts_data[mb_inds]

        # forward and update
        opt.zero_grad()

        ys = model(Xs)

        loss = cfg.TRAIN.LOSS_FUNCTION(ys, ts)
        loss.backward()
        opt.step()
    
        preds = ys.argmax(dim=1, keepdim=True).reshape(-1)
        accuracy = (preds == ts).sum() / float(cfg.TRAIN.MINIBATCH)

        _loss = loss.item()
        _accuracy = accuracy.item()

        progres_bar += '|'

        if (i + 1) % 10 == 0:
            progres_bar += str(i + 1)

            # save process result
            if cfg.TRAIN.LEARNING_PROCESS_RESULT_SAVE:
                list_iter.append(i + 1)
                list_loss.append(_loss)
                list_accuracy.append(_accuracy)

        print('\r' + 'Loss:{:.4f}, Accu:{:.4f} '.format(_loss, _accuracy) + progres_bar, end='')

                
        # display training state
        if (i + 1) % cfg.TRAIN.DISPAY_ITERATION_INTERVAL == 0:
            print('\r' + ' ' * len(progres_bar), end='')
            print('\rIter:{}, Loss:{:.4f}, Accu:{:.4f}'.format(i + 1, _loss, _accuracy))
            progres_bar = ''

        # save parameters
        if (cfg.TRAIN.MODEL_SAVE_INTERVAL != False) and ((i + 1) % cfg.TRAIN.MODEL_SAVE_INTERVAL == 0):
            save_path = cfg.TRAIN.MODEL_SAVE_PATH.format('iter{}'.format(i + 1))
            torch.save(model.state_dict(), save_path)
            print('save >> {}'.format(save_path))


    save_path = cfg.TRAIN.MODEL_SAVE_PATH.format('final')
    torch.save(model.state_dict(), save_path)
    print('final paramters were saved to >> {}'.format(save_path))

    if cfg.TRAIN.LEARNING_PROCESS_RESULT_SAVE:
        f = open(cfg.TRAIN.LEARNING_PROCESS_RESULT_LOSS_PATH, 'w')
        df = pd.DataFrame({'iteration' : list_iter, 'loss' : list_loss, 'accuracy' : list_accuracy})
        df.to_csv(cfg.TRAIN.LEARNING_PROCESS_RESULT_LOSS_PATH, index=False)
        print('loss was saved to >> {}'.format(cfg.TRAIN.LEARNING_PROCESS_RESULT_LOSS_PATH))

train()
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 16, 16]           9,472
#        BatchNorm2d-2           [-1, 64, 16, 16]             128
#             Conv2d-3             [-1, 64, 8, 8]           4,160
#        BatchNorm2d-4             [-1, 64, 8, 8]             128
#               ReLU-5             [-1, 64, 8, 8]               0
#             Conv2d-6             [-1, 64, 8, 8]           1,216
#        BatchNorm2d-7             [-1, 64, 8, 8]             128
#               ReLU-8             [-1, 64, 8, 8]               0
#             Conv2d-9            [-1, 256, 8, 8]          16,640
#       BatchNorm2d-10            [-1, 256, 8, 8]             512
#              ReLU-11            [-1, 256, 8, 8]               0
#            Conv2d-12            [-1, 256, 8, 8]          16,640
#      ResNeXtBlock-13            [-1, 256, 8, 8]               0
#            Conv2d-14             [-1, 64, 8, 8]          16,448
#       BatchNorm2d-15             [-1, 64, 8, 8]             128
#              ReLU-16             [-1, 64, 8, 8]               0
#            Conv2d-17             [-1, 64, 8, 8]           1,216
#       BatchNorm2d-18             [-1, 64, 8, 8]             128
#              ReLU-19             [-1, 64, 8, 8]               0
#            Conv2d-20            [-1, 256, 8, 8]          16,640
#       BatchNorm2d-21            [-1, 256, 8, 8]             512
#              ReLU-22            [-1, 256, 8, 8]               0
#      ResNeXtBlock-23            [-1, 256, 8, 8]               0
#            Conv2d-24             [-1, 64, 8, 8]          16,448
#       BatchNorm2d-25             [-1, 64, 8, 8]             128
#              ReLU-26             [-1, 64, 8, 8]               0
#            Conv2d-27             [-1, 64, 8, 8]           1,216
#       BatchNorm2d-28             [-1, 64, 8, 8]             128
#              ReLU-29             [-1, 64, 8, 8]               0
#            Conv2d-30            [-1, 256, 8, 8]          16,640
#       BatchNorm2d-31            [-1, 256, 8, 8]             512
#              ReLU-32            [-1, 256, 8, 8]               0
#      ResNeXtBlock-33            [-1, 256, 8, 8]               0
#            Conv2d-34            [-1, 128, 4, 4]          32,896
#       BatchNorm2d-35            [-1, 128, 4, 4]             256
#              ReLU-36            [-1, 128, 4, 4]               0
#            Conv2d-37            [-1, 128, 4, 4]           4,736
#       BatchNorm2d-38            [-1, 128, 4, 4]             256
#              ReLU-39            [-1, 128, 4, 4]               0
#            Conv2d-40            [-1, 512, 4, 4]          66,048
#       BatchNorm2d-41            [-1, 512, 4, 4]           1,024
#              ReLU-42            [-1, 512, 4, 4]               0
#            Conv2d-43            [-1, 512, 8, 8]         131,584
#      ResNeXtBlock-44            [-1, 512, 4, 4]               0
#            Conv2d-45            [-1, 128, 4, 4]          65,664
#       BatchNorm2d-46            [-1, 128, 4, 4]             256
#              ReLU-47            [-1, 128, 4, 4]               0
#            Conv2d-48            [-1, 128, 4, 4]           4,736
#       BatchNorm2d-49            [-1, 128, 4, 4]             256
#              ReLU-50            [-1, 128, 4, 4]               0
#            Conv2d-51            [-1, 512, 4, 4]          66,048
#       BatchNorm2d-52            [-1, 512, 4, 4]           1,024
#              ReLU-53            [-1, 512, 4, 4]               0
#      ResNeXtBlock-54            [-1, 512, 4, 4]               0
#            Conv2d-55            [-1, 128, 4, 4]          65,664
#       BatchNorm2d-56            [-1, 128, 4, 4]             256
#              ReLU-57            [-1, 128, 4, 4]               0
#            Conv2d-58            [-1, 128, 4, 4]           4,736
#       BatchNorm2d-59            [-1, 128, 4, 4]             256
#              ReLU-60            [-1, 128, 4, 4]               0
#            Conv2d-61            [-1, 512, 4, 4]          66,048
#       BatchNorm2d-62            [-1, 512, 4, 4]           1,024
#              ReLU-63            [-1, 512, 4, 4]               0
#      ResNeXtBlock-64            [-1, 512, 4, 4]               0
#            Conv2d-65            [-1, 128, 4, 4]          65,664
#       BatchNorm2d-66            [-1, 128, 4, 4]             256
#              ReLU-67            [-1, 128, 4, 4]               0
#            Conv2d-68            [-1, 128, 4, 4]           4,736
#       BatchNorm2d-69            [-1, 128, 4, 4]             256
#              ReLU-70            [-1, 128, 4, 4]               0
#            Conv2d-71            [-1, 512, 4, 4]          66,048
#       BatchNorm2d-72            [-1, 512, 4, 4]           1,024
#              ReLU-73            [-1, 512, 4, 4]               0
#      ResNeXtBlock-74            [-1, 512, 4, 4]               0
#            Conv2d-75            [-1, 256, 2, 2]         131,328
#       BatchNorm2d-76            [-1, 256, 2, 2]             512
#              ReLU-77            [-1, 256, 2, 2]               0
#            Conv2d-78            [-1, 256, 2, 2]          18,688
#       BatchNorm2d-79            [-1, 256, 2, 2]             512
#              ReLU-80            [-1, 256, 2, 2]               0
#            Conv2d-81           [-1, 1024, 2, 2]         263,168
#       BatchNorm2d-82           [-1, 1024, 2, 2]           2,048
#              ReLU-83           [-1, 1024, 2, 2]               0
#            Conv2d-84           [-1, 1024, 4, 4]         525,312
#      ResNeXtBlock-85           [-1, 1024, 2, 2]               0
#            Conv2d-86            [-1, 256, 2, 2]         262,400
#       BatchNorm2d-87            [-1, 256, 2, 2]             512
#              ReLU-88            [-1, 256, 2, 2]               0
#            Conv2d-89            [-1, 256, 2, 2]          18,688
#       BatchNorm2d-90            [-1, 256, 2, 2]             512
#              ReLU-91            [-1, 256, 2, 2]               0
#            Conv2d-92           [-1, 1024, 2, 2]         263,168
#       BatchNorm2d-93           [-1, 1024, 2, 2]           2,048
#              ReLU-94           [-1, 1024, 2, 2]               0
#      ResNeXtBlock-95           [-1, 1024, 2, 2]               0
#            Conv2d-96            [-1, 256, 2, 2]         262,400
#       BatchNorm2d-97            [-1, 256, 2, 2]             512
#              ReLU-98            [-1, 256, 2, 2]               0
#            Conv2d-99            [-1, 256, 2, 2]          18,688
#      BatchNorm2d-100            [-1, 256, 2, 2]             512
#             ReLU-101            [-1, 256, 2, 2]               0
#           Conv2d-102           [-1, 1024, 2, 2]         263,168
#      BatchNorm2d-103           [-1, 1024, 2, 2]           2,048
#             ReLU-104           [-1, 1024, 2, 2]               0
#     ResNeXtBlock-105           [-1, 1024, 2, 2]               0
#           Conv2d-106            [-1, 256, 2, 2]         262,400
#      BatchNorm2d-107            [-1, 256, 2, 2]             512
#             ReLU-108            [-1, 256, 2, 2]               0
#           Conv2d-109            [-1, 256, 2, 2]          18,688
#      BatchNorm2d-110            [-1, 256, 2, 2]             512
#             ReLU-111            [-1, 256, 2, 2]               0
#           Conv2d-112           [-1, 1024, 2, 2]         263,168
#      BatchNorm2d-113           [-1, 1024, 2, 2]           2,048
#             ReLU-114           [-1, 1024, 2, 2]               0
#     ResNeXtBlock-115           [-1, 1024, 2, 2]               0
#           Conv2d-116            [-1, 256, 2, 2]         262,400
#      BatchNorm2d-117            [-1, 256, 2, 2]             512
#             ReLU-118            [-1, 256, 2, 2]               0
#           Conv2d-119            [-1, 256, 2, 2]          18,688
#      BatchNorm2d-120            [-1, 256, 2, 2]             512
#             ReLU-121            [-1, 256, 2, 2]               0
#           Conv2d-122           [-1, 1024, 2, 2]         263,168
#      BatchNorm2d-123           [-1, 1024, 2, 2]           2,048
#             ReLU-124           [-1, 1024, 2, 2]               0
#     ResNeXtBlock-125           [-1, 1024, 2, 2]               0
#           Conv2d-126            [-1, 256, 2, 2]         262,400
#      BatchNorm2d-127            [-1, 256, 2, 2]             512
#             ReLU-128            [-1, 256, 2, 2]               0
#           Conv2d-129            [-1, 256, 2, 2]          18,688
#      BatchNorm2d-130            [-1, 256, 2, 2]             512
#             ReLU-131            [-1, 256, 2, 2]               0
#           Conv2d-132           [-1, 1024, 2, 2]         263,168
#      BatchNorm2d-133           [-1, 1024, 2, 2]           2,048
#             ReLU-134           [-1, 1024, 2, 2]               0
#     ResNeXtBlock-135           [-1, 1024, 2, 2]               0
#           Conv2d-136            [-1, 512, 1, 1]         524,800
#      BatchNorm2d-137            [-1, 512, 1, 1]           1,024
#             ReLU-138            [-1, 512, 1, 1]               0
#           Conv2d-139            [-1, 512, 1, 1]          74,240
#      BatchNorm2d-140            [-1, 512, 1, 1]           1,024
#             ReLU-141            [-1, 512, 1, 1]               0
#           Conv2d-142           [-1, 2048, 1, 1]       1,050,624
#      BatchNorm2d-143           [-1, 2048, 1, 1]           4,096
#             ReLU-144           [-1, 2048, 1, 1]               0
#           Conv2d-145           [-1, 2048, 2, 2]       2,099,200
#     ResNeXtBlock-146           [-1, 2048, 1, 1]               0
#           Conv2d-147            [-1, 512, 1, 1]       1,049,088
#      BatchNorm2d-148            [-1, 512, 1, 1]           1,024
#             ReLU-149            [-1, 512, 1, 1]               0
#           Conv2d-150            [-1, 512, 1, 1]          74,240
#      BatchNorm2d-151            [-1, 512, 1, 1]           1,024
#             ReLU-152            [-1, 512, 1, 1]               0
#           Conv2d-153           [-1, 2048, 1, 1]       1,050,624
#      BatchNorm2d-154           [-1, 2048, 1, 1]           4,096
#             ReLU-155           [-1, 2048, 1, 1]               0
#     ResNeXtBlock-156           [-1, 2048, 1, 1]               0
#           Conv2d-157            [-1, 512, 1, 1]       1,049,088
#      BatchNorm2d-158            [-1, 512, 1, 1]           1,024
#             ReLU-159            [-1, 512, 1, 1]               0
#           Conv2d-160            [-1, 512, 1, 1]          74,240
#      BatchNorm2d-161            [-1, 512, 1, 1]           1,024
#             ReLU-162            [-1, 512, 1, 1]               0
#           Conv2d-163           [-1, 2048, 1, 1]       1,050,624
#      BatchNorm2d-164           [-1, 2048, 1, 1]           4,096
#             ReLU-165           [-1, 2048, 1, 1]               0
#     ResNeXtBlock-166           [-1, 2048, 1, 1]               0
#           Linear-167                  [-1, 100]         204,900
# ================================================================
# Total params: 12,768,228
# Trainable params: 12,768,228
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 5.54
# Params size (MB): 48.71
# Estimated Total Size (MB): 54.26
# ----------------------------------------------------------------
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/cifar-100-python.tar.gz to ./data/
# training start
#
# Iter:50, Loss:5.3595, Accu:0.0000
# Iter:100, Loss:4.8275, Accu:0.0000
# Iter:150, Loss:4.8607, Accu:0.0312
# Iter:200, Loss:4.7042, Accu:0.0312
# save >> models/ResNeXt50_iter200.pt
# Iter:250, Loss:4.4805, Accu:0.0000
# Iter:300, Loss:4.5440, Accu:0.0625
# Iter:350, Loss:4.6128, Accu:0.0156
# Iter:400, Loss:4.1727, Accu:0.0469
# save >> models/ResNeXt50_iter400.pt
# Iter:450, Loss:4.1479, Accu:0.0469
# Iter:500, Loss:4.1777, Accu:0.1094
# Iter:550, Loss:4.1609, Accu:0.0625
# Iter:600, Loss:4.1985, Accu:0.0469
# save >> models/ResNeXt50_iter600.pt
# Iter:650, Loss:4.0302, Accu:0.1094
# Iter:700, Loss:4.1143, Accu:0.1094
# Iter:750, Loss:4.1765, Accu:0.0781
# Iter:800, Loss:3.9055, Accu:0.0938
# save >> models/ResNeXt50_iter800.pt
# Iter:850, Loss:4.1892, Accu:0.0625
# Iter:900, Loss:3.8408, Accu:0.1094
# Iter:950, Loss:3.8742, Accu:0.1094
# Iter:1000, Loss:3.8480, Accu:0.0781
# save >> models/ResNeXt50_iter1000.pt
# Iter:1050, Loss:3.9156, Accu:0.1250
# Iter:1100, Loss:3.9020, Accu:0.0781
# Iter:1150, Loss:3.8952, Accu:0.0625
# Iter:1200, Loss:3.8655, Accu:0.0781
# save >> models/ResNeXt50_iter1200.pt
# Iter:1250, Loss:3.7657, Accu:0.0625
# Iter:1300, Loss:3.7019, Accu:0.0781
# Iter:1350, Loss:3.6720, Accu:0.1719
# Iter:1400, Loss:3.9471, Accu:0.1094
# save >> models/ResNeXt50_iter1400.pt
# Iter:1450, Loss:3.7182, Accu:0.1250
# Iter:1500, Loss:3.5718, Accu:0.1875
# Iter:1550, Loss:3.9838, Accu:0.0938
# Iter:1600, Loss:4.1344, Accu:0.0312
# save >> models/ResNeXt50_iter1600.pt
# Iter:1650, Loss:3.4920, Accu:0.2031
# Iter:1700, Loss:3.4538, Accu:0.1719
# Iter:1750, Loss:3.5075, Accu:0.1250
# Iter:1800, Loss:3.6923, Accu:0.1406
# save >> models/ResNeXt50_iter1800.pt
# Iter:1850, Loss:3.7602, Accu:0.0781
# Iter:1900, Loss:3.3205, Accu:0.1875
# Iter:1950, Loss:3.5387, Accu:0.2188
# Iter:2000, Loss:3.7189, Accu:0.2031
# save >> models/ResNeXt50_iter2000.pt
# Iter:2050, Loss:3.3006, Accu:0.2031
# Iter:2100, Loss:3.5845, Accu:0.1562
# Iter:2150, Loss:3.5759, Accu:0.2031
# Iter:2200, Loss:3.6771, Accu:0.0781
# save >> models/ResNeXt50_iter2200.pt
# Iter:2250, Loss:3.2332, Accu:0.2656
# Iter:2300, Loss:3.8518, Accu:0.1094
# Iter:2350, Loss:3.3215, Accu:0.1250
# Iter:2400, Loss:3.3355, Accu:0.2812
# save >> models/ResNeXt50_iter2400.pt
# Iter:2450, Loss:3.0409, Accu:0.2656
# Iter:2500, Loss:3.0721, Accu:0.1875
# Iter:2550, Loss:3.2059, Accu:0.2188
# Iter:2600, Loss:3.0108, Accu:0.2344
# save >> models/ResNeXt50_iter2600.pt
# Iter:2650, Loss:3.1354, Accu:0.2031
# Iter:2700, Loss:3.4130, Accu:0.1406
# Iter:2750, Loss:3.4274, Accu:0.1562
# Iter:2800, Loss:3.5747, Accu:0.1719
# save >> models/ResNeXt50_iter2800.pt
# Iter:2850, Loss:3.0404, Accu:0.2188
# Iter:2900, Loss:3.4526, Accu:0.2656
# Iter:2950, Loss:3.1636, Accu:0.2188
# Iter:3000, Loss:3.2397, Accu:0.1406
# save >> models/ResNeXt50_iter3000.pt
# Iter:3050, Loss:3.0808, Accu:0.2500
# Iter:3100, Loss:3.5784, Accu:0.1562
# Iter:3150, Loss:3.3027, Accu:0.2031
# Iter:3200, Loss:2.9648, Accu:0.2969
# save >> models/ResNeXt50_iter3200.pt
# Iter:3250, Loss:3.7228, Accu:0.1250
# Iter:3300, Loss:2.9749, Accu:0.2500
# Iter:3350, Loss:2.8361, Accu:0.2188
# Iter:3400, Loss:3.1424, Accu:0.2344
# save >> models/ResNeXt50_iter3400.pt
# Iter:3450, Loss:3.2819, Accu:0.1406
# Iter:3500, Loss:3.1781, Accu:0.1875
# Iter:3550, Loss:3.1526, Accu:0.2188
# Iter:3600, Loss:3.4696, Accu:0.2188
# save >> models/ResNeXt50_iter3600.pt
# Iter:3650, Loss:3.6805, Accu:0.1562
# Iter:3700, Loss:2.8797, Accu:0.2969
# Iter:3750, Loss:2.9516, Accu:0.2969
# Iter:3800, Loss:2.7542, Accu:0.3906
# save >> models/ResNeXt50_iter3800.pt
# Iter:3850, Loss:3.0520, Accu:0.2812
# Iter:3900, Loss:3.1135, Accu:0.2500
# Iter:3950, Loss:3.2372, Accu:0.2031
# Iter:4000, Loss:2.8705, Accu:0.2656
# save >> models/ResNeXt50_iter4000.pt
# Iter:4050, Loss:2.7532, Accu:0.2969
# Iter:4100, Loss:2.9305, Accu:0.2812
# Iter:4150, Loss:2.9057, Accu:0.1875
# Iter:4200, Loss:3.3432, Accu:0.2031
# save >> models/ResNeXt50_iter4200.pt
# Iter:4250, Loss:3.2796, Accu:0.2500
# Iter:4300, Loss:2.9789, Accu:0.1875
# Iter:4350, Loss:2.8899, Accu:0.2969
# Iter:4400, Loss:2.6431, Accu:0.3281
# save >> models/ResNeXt50_iter4400.pt
# Iter:4450, Loss:2.8264, Accu:0.2344
# Iter:4500, Loss:3.0386, Accu:0.2344
# Iter:4550, Loss:2.7318, Accu:0.3125
# Iter:4600, Loss:3.3533, Accu:0.2188
# save >> models/ResNeXt50_iter4600.pt
# Iter:4650, Loss:3.0055, Accu:0.2188
# Iter:4700, Loss:2.2808, Accu:0.4531
# Iter:4750, Loss:2.3884, Accu:0.4219
# Iter:4800, Loss:2.6824, Accu:0.2812
# save >> models/ResNeXt50_iter4800.pt
# Iter:4850, Loss:2.6670, Accu:0.3281
# Iter:4900, Loss:2.7904, Accu:0.2812
# Iter:4950, Loss:2.1335, Accu:0.4844
# Iter:5000, Loss:2.8210, Accu:0.2969
# save >> models/ResNeXt50_iter5000.pt
# Iter:5050, Loss:2.6419, Accu:0.2656
# Iter:5100, Loss:2.9698, Accu:0.2969
# Iter:5150, Loss:2.6840, Accu:0.2969
# Iter:5200, Loss:2.4146, Accu:0.3438
# save >> models/ResNeXt50_iter5200.pt
# Iter:5250, Loss:2.6736, Accu:0.3281
# Iter:5300, Loss:2.8433, Accu:0.3438
# Iter:5350, Loss:2.1139, Accu:0.4375
# Iter:5400, Loss:2.7356, Accu:0.3281
# save >> models/ResNeXt50_iter5400.pt
# Iter:5450, Loss:2.5160, Accu:0.3125
# Iter:5500, Loss:2.3567, Accu:0.3594
# Iter:5550, Loss:2.5063, Accu:0.4062
# Iter:5600, Loss:2.4579, Accu:0.3906
# save >> models/ResNeXt50_iter5600.pt
# Iter:5650, Loss:3.0869, Accu:0.2656
# Iter:5700, Loss:2.4659, Accu:0.3750
# Iter:5750, Loss:2.6090, Accu:0.2969
# Iter:5800, Loss:2.0911, Accu:0.4375
# save >> models/ResNeXt50_iter5800.pt
# Iter:5850, Loss:2.3926, Accu:0.3750
# Iter:5900, Loss:2.5767, Accu:0.3438
# Iter:5950, Loss:2.8239, Accu:0.2812
# Iter:6000, Loss:2.4760, Accu:0.3125
# save >> models/ResNeXt50_iter6000.pt
# Iter:6050, Loss:2.8253, Accu:0.2969
# Iter:6100, Loss:2.8583, Accu:0.2969
# Iter:6150, Loss:2.5554, Accu:0.3281
# Iter:6200, Loss:2.5607, Accu:0.3125
# save >> models/ResNeXt50_iter6200.pt
# Iter:6250, Loss:2.3820, Accu:0.4062
# Iter:6300, Loss:2.5157, Accu:0.3906
# Iter:6350, Loss:2.1900, Accu:0.4375
# Iter:6400, Loss:2.2839, Accu:0.3594
# save >> models/ResNeXt50_iter6400.pt
# Iter:6450, Loss:2.7742, Accu:0.2969
# Iter:6500, Loss:2.6605, Accu:0.3281
# Iter:6550, Loss:2.7633, Accu:0.2188
# Iter:6600, Loss:2.4448, Accu:0.3281
# save >> models/ResNeXt50_iter6600.pt
# Iter:6650, Loss:2.4906, Accu:0.3125
# Iter:6700, Loss:2.4134, Accu:0.3594
# Iter:6750, Loss:2.5167, Accu:0.3125
# Iter:6800, Loss:2.4416, Accu:0.3438
# save >> models/ResNeXt50_iter6800.pt
# Iter:6850, Loss:2.3465, Accu:0.4062
# Iter:6900, Loss:2.5519, Accu:0.3125
# Iter:6950, Loss:2.2615, Accu:0.3906
# Iter:7000, Loss:2.3155, Accu:0.3750
# save >> models/ResNeXt50_iter7000.pt
# Iter:7050, Loss:1.6697, Accu:0.5781
# Iter:7100, Loss:1.9611, Accu:0.3750
# Iter:7150, Loss:2.2428, Accu:0.4375
# Iter:7200, Loss:1.9295, Accu:0.4375
# save >> models/ResNeXt50_iter7200.pt
# Iter:7250, Loss:2.4286, Accu:0.2969
# Iter:7300, Loss:2.2220, Accu:0.4219
# Iter:7350, Loss:2.3019, Accu:0.4531
# Iter:7400, Loss:2.3174, Accu:0.4375
# save >> models/ResNeXt50_iter7400.pt
# Iter:7450, Loss:2.1401, Accu:0.4062
# Iter:7500, Loss:1.9449, Accu:0.5000
# Iter:7550, Loss:2.1398, Accu:0.4062
# Iter:7600, Loss:2.1801, Accu:0.4844
# save >> models/ResNeXt50_iter7600.pt
# Iter:7650, Loss:2.2317, Accu:0.3906
# Iter:7700, Loss:2.4611, Accu:0.2969
# Iter:7750, Loss:2.5079, Accu:0.3594
# Iter:7800, Loss:2.2712, Accu:0.3906
# save >> models/ResNeXt50_iter7800.pt
# Iter:7850, Loss:2.2721, Accu:0.4219
# Iter:7900, Loss:2.1380, Accu:0.4688
# Iter:7950, Loss:1.7973, Accu:0.5312
# Iter:8000, Loss:2.0237, Accu:0.3594
# save >> models/ResNeXt50_iter8000.pt
# Iter:8050, Loss:2.5608, Accu:0.3750
# Iter:8100, Loss:1.9895, Accu:0.4688
# Iter:8150, Loss:2.1311, Accu:0.3438
# Iter:8200, Loss:2.2557, Accu:0.3750
# save >> models/ResNeXt50_iter8200.pt
# Iter:8250, Loss:2.2582, Accu:0.4844
# Iter:8300, Loss:2.0680, Accu:0.4531
# Iter:8350, Loss:2.7612, Accu:0.3438
# Iter:8400, Loss:2.2695, Accu:0.3750
# save >> models/ResNeXt50_iter8400.pt
# Iter:8450, Loss:1.9711, Accu:0.4375
# Iter:8500, Loss:2.1476, Accu:0.4688
# Iter:8550, Loss:1.9688, Accu:0.4844
# Iter:8600, Loss:1.9066, Accu:0.4688
# save >> models/ResNeXt50_iter8600.pt
# Iter:8650, Loss:1.7785, Accu:0.5469
# Iter:8700, Loss:2.0828, Accu:0.4688
# Iter:8750, Loss:1.5322, Accu:0.6719
# Iter:8800, Loss:1.9288, Accu:0.5156
# save >> models/ResNeXt50_iter8800.pt
# Iter:8850, Loss:1.9027, Accu:0.5000
# Iter:8900, Loss:2.5554, Accu:0.3906
# Iter:8950, Loss:2.0440, Accu:0.3906
# Iter:9000, Loss:1.9928, Accu:0.5312
# save >> models/ResNeXt50_iter9000.pt
# Iter:9050, Loss:2.0475, Accu:0.4688
# Iter:9100, Loss:2.2870, Accu:0.3438
# Iter:9150, Loss:2.5642, Accu:0.4062
# Iter:9200, Loss:2.1933, Accu:0.3594
# save >> models/ResNeXt50_iter9200.pt
# Iter:9250, Loss:2.3081, Accu:0.4375
# Iter:9300, Loss:1.8018, Accu:0.5312
# Iter:9350, Loss:1.7854, Accu:0.5312
# Iter:9400, Loss:1.2878, Accu:0.5781
# save >> models/ResNeXt50_iter9400.pt
# Iter:9450, Loss:1.7972, Accu:0.4688
# Iter:9500, Loss:1.3924, Accu:0.6250
# Iter:9550, Loss:1.5342, Accu:0.5312
# Iter:9600, Loss:1.5239, Accu:0.6406
# save >> models/ResNeXt50_iter9600.pt
# Iter:9650, Loss:1.3367, Accu:0.6406
# Iter:9700, Loss:1.8748, Accu:0.4688
# Iter:9750, Loss:1.9971, Accu:0.5000
# Iter:9800, Loss:1.8329, Accu:0.5469
# save >> models/ResNeXt50_iter9800.pt
# Iter:9850, Loss:1.7191, Accu:0.5469
# Iter:9900, Loss:1.7510, Accu:0.5156
# Iter:9950, Loss:1.3871, Accu:0.6562
# Iter:10000, Loss:1.7416, Accu:0.5312
# save >> models/ResNeXt50_iter10000.pt
# Iter:10050, Loss:1.9467, Accu:0.5000
# Iter:10100, Loss:2.2753, Accu:0.3750
# Iter:10150, Loss:2.0323, Accu:0.5000
# Iter:10200, Loss:1.3323, Accu:0.7031
# save >> models/ResNeXt50_iter10200.pt
# Iter:10250, Loss:1.3664, Accu:0.6250
# Iter:10300, Loss:1.5958, Accu:0.5312
# Iter:10350, Loss:1.1659, Accu:0.6562
# Iter:10400, Loss:1.3256, Accu:0.6250
# save >> models/ResNeXt50_iter10400.pt
# Iter:10450, Loss:1.2362, Accu:0.6875
# Iter:10500, Loss:1.3545, Accu:0.6094
# Iter:10550, Loss:1.9083, Accu:0.3906
# Iter:10600, Loss:1.6596, Accu:0.5000
# save >> models/ResNeXt50_iter10600.pt
# Iter:10650, Loss:1.2625, Accu:0.5469
# Iter:10700, Loss:1.8669, Accu:0.5312
# Iter:10750, Loss:1.6228, Accu:0.5625
# Iter:10800, Loss:1.6069, Accu:0.5469
# save >> models/ResNeXt50_iter10800.pt
# Iter:10850, Loss:2.0233, Accu:0.3750
# Iter:10900, Loss:1.5123, Accu:0.5938
# Iter:10950, Loss:1.1176, Accu:0.6406
# Iter:11000, Loss:1.1788, Accu:0.6562
# save >> models/ResNeXt50_iter11000.pt
# Iter:11050, Loss:1.3237, Accu:0.6719
# Iter:11100, Loss:1.2466, Accu:0.6250
# Iter:11150, Loss:1.3897, Accu:0.5312
# Iter:11200, Loss:1.0296, Accu:0.7188
# save >> models/ResNeXt50_iter11200.pt
# Iter:11250, Loss:1.4338, Accu:0.5781
# Iter:11300, Loss:1.2510, Accu:0.6406
# Iter:11350, Loss:1.9227, Accu:0.5000
# Iter:11400, Loss:1.8913, Accu:0.4531
# save >> models/ResNeXt50_iter11400.pt
# Iter:11450, Loss:1.7411, Accu:0.5156
# Iter:11500, Loss:1.9714, Accu:0.4375
# Iter:11550, Loss:1.5011, Accu:0.6094
# Iter:11600, Loss:1.7729, Accu:0.5000
# save >> models/ResNeXt50_iter11600.pt
# Iter:11650, Loss:1.2912, Accu:0.6250
# Iter:11700, Loss:1.8339, Accu:0.5000
# Iter:11750, Loss:1.3411, Accu:0.5781
# Iter:11800, Loss:1.2880, Accu:0.6406
# save >> models/ResNeXt50_iter11800.pt
# Iter:11850, Loss:1.3399, Accu:0.6094
# Iter:11900, Loss:1.1591, Accu:0.6719
# Iter:11950, Loss:1.2342, Accu:0.6406
# Iter:12000, Loss:1.2800, Accu:0.6094
# save >> models/ResNeXt50_iter12000.pt
# Iter:12050, Loss:1.5608, Accu:0.5938
# Iter:12100, Loss:1.2812, Accu:0.6406
# Iter:12150, Loss:1.6486, Accu:0.5625
# Iter:12200, Loss:1.2223, Accu:0.5938
# save >> models/ResNeXt50_iter12200.pt
# Iter:12250, Loss:1.5726, Accu:0.5781
# Iter:12300, Loss:1.3531, Accu:0.6562
# Iter:12350, Loss:1.5804, Accu:0.5625
# Iter:12400, Loss:1.4598, Accu:0.5312
# save >> models/ResNeXt50_iter12400.pt
# Iter:12450, Loss:1.6969, Accu:0.5000
# Iter:12500, Loss:1.3955, Accu:0.6250
# Iter:12550, Loss:0.9995, Accu:0.6719
# Iter:12600, Loss:0.9118, Accu:0.7812
# save >> models/ResNeXt50_iter12600.pt
# Iter:12650, Loss:1.3427, Accu:0.5938
# Iter:12700, Loss:1.0977, Accu:0.6562
# Iter:12750, Loss:1.4343, Accu:0.6562
# Iter:12800, Loss:1.0631, Accu:0.7031
# save >> models/ResNeXt50_iter12800.pt
# Iter:12850, Loss:1.4298, Accu:0.6406
# Iter:12900, Loss:1.2379, Accu:0.6406
# Iter:12950, Loss:1.2514, Accu:0.6562
# Iter:13000, Loss:1.3018, Accu:0.6406
# save >> models/ResNeXt50_iter13000.pt
# Iter:13050, Loss:1.2151, Accu:0.7031
# Iter:13100, Loss:1.0896, Accu:0.6562
# Iter:13150, Loss:0.9897, Accu:0.6719
# Iter:13200, Loss:1.4172, Accu:0.5625
# save >> models/ResNeXt50_iter13200.pt
# Iter:13250, Loss:1.1782, Accu:0.7188
# Iter:13300, Loss:0.8326, Accu:0.7500
# Iter:13350, Loss:1.2855, Accu:0.6250
# Iter:13400, Loss:1.1191, Accu:0.6406
# save >> models/ResNeXt50_iter13400.pt
# Iter:13450, Loss:0.9623, Accu:0.7031
# Iter:13500, Loss:1.1371, Accu:0.6719
# Iter:13550, Loss:0.9468, Accu:0.6875
# Iter:13600, Loss:1.0022, Accu:0.7031
# save >> models/ResNeXt50_iter13600.pt
# Iter:13650, Loss:0.8854, Accu:0.6719
# Iter:13700, Loss:1.0845, Accu:0.7344
# Iter:13750, Loss:1.3984, Accu:0.5469
# Iter:13800, Loss:1.5442, Accu:0.5625
# save >> models/ResNeXt50_iter13800.pt
# Iter:13850, Loss:1.0736, Accu:0.6406
# Iter:13900, Loss:1.4815, Accu:0.5625
# Iter:13950, Loss:1.5498, Accu:0.5469
# Iter:14000, Loss:1.3705, Accu:0.5938
# save >> models/ResNeXt50_iter14000.pt
# Iter:14050, Loss:1.2513, Accu:0.6406
# Iter:14100, Loss:0.9909, Accu:0.7188
# Iter:14150, Loss:0.6664, Accu:0.8281
# Iter:14200, Loss:0.7223, Accu:0.7969
# save >> models/ResNeXt50_iter14200.pt
# Iter:14250, Loss:0.9194, Accu:0.7031
# Iter:14300, Loss:1.2357, Accu:0.5938
# Iter:14350, Loss:0.9786, Accu:0.7500
# Iter:14400, Loss:0.7936, Accu:0.7344
# save >> models/ResNeXt50_iter14400.pt
# Iter:14450, Loss:0.9098, Accu:0.7656
# Iter:14500, Loss:1.2133, Accu:0.6562
# Iter:14550, Loss:1.2168, Accu:0.6406
# Iter:14600, Loss:1.4288, Accu:0.5781
# save >> models/ResNeXt50_iter14600.pt
# Iter:14650, Loss:1.0220, Accu:0.7344
# Iter:14700, Loss:0.9239, Accu:0.7188
# Iter:14750, Loss:1.2841, Accu:0.6406
# Iter:14800, Loss:1.1142, Accu:0.7188
# save >> models/ResNeXt50_iter14800.pt
# Iter:14850, Loss:1.1142, Accu:0.6562
# Iter:14900, Loss:0.8385, Accu:0.7344
# Iter:14950, Loss:0.8949, Accu:0.6562
# Iter:15000, Loss:0.6760, Accu:0.7969
# save >> models/ResNeXt50_iter15000.pt
# Iter:15050, Loss:0.5683, Accu:0.8438
# Iter:15100, Loss:0.9479, Accu:0.6875
# Iter:15150, Loss:0.6834, Accu:0.7656
# Iter:15200, Loss:0.5695, Accu:0.8750
# save >> models/ResNeXt50_iter15200.pt
# Iter:15250, Loss:0.8100, Accu:0.7500
# Iter:15300, Loss:0.8747, Accu:0.7031
# Iter:15350, Loss:1.3236, Accu:0.6094
# Iter:15400, Loss:1.0055, Accu:0.6875
# save >> models/ResNeXt50_iter15400.pt
# Iter:15450, Loss:1.0130, Accu:0.6562
# Iter:15500, Loss:0.7595, Accu:0.7188
# Iter:15550, Loss:1.1128, Accu:0.6562
# Iter:15600, Loss:1.1601, Accu:0.6406
# save >> models/ResNeXt50_iter15600.pt
# Iter:15650, Loss:0.5597, Accu:0.8125
# Iter:15700, Loss:0.9598, Accu:0.7500
# Iter:15750, Loss:0.5982, Accu:0.8125
# Iter:15800, Loss:0.7753, Accu:0.8125
# save >> models/ResNeXt50_iter15800.pt
# Iter:15850, Loss:0.9433, Accu:0.7031
# Iter:15900, Loss:0.5602, Accu:0.7812
# Iter:15950, Loss:0.7501, Accu:0.7656
# Iter:16000, Loss:0.8244, Accu:0.7812
# save >> models/ResNeXt50_iter16000.pt
# Iter:16050, Loss:0.5558, Accu:0.7812
# Iter:16100, Loss:0.7253, Accu:0.7656
# Iter:16150, Loss:0.9745, Accu:0.7656
# Iter:16200, Loss:0.9383, Accu:0.6719
# save >> models/ResNeXt50_iter16200.pt
# Iter:16250, Loss:0.6202, Accu:0.8125
# Iter:16300, Loss:0.7908, Accu:0.7812
# Iter:16350, Loss:0.8808, Accu:0.7031
# Iter:16400, Loss:0.9832, Accu:0.7500
# save >> models/ResNeXt50_iter16400.pt
# Iter:16450, Loss:0.8447, Accu:0.7344
# Iter:16500, Loss:0.7178, Accu:0.7656
# Iter:16550, Loss:0.8459, Accu:0.7188
# Iter:16600, Loss:0.5887, Accu:0.7969
# save >> models/ResNeXt50_iter16600.pt
# Iter:16650, Loss:0.6737, Accu:0.8438
# Iter:16700, Loss:0.6218, Accu:0.7812
# Iter:16750, Loss:0.6242, Accu:0.8438
# Iter:16800, Loss:0.3954, Accu:0.9062
# save >> models/ResNeXt50_iter16800.pt
# Iter:16850, Loss:0.7738, Accu:0.7500
# Iter:16900, Loss:0.6714, Accu:0.8281
# Iter:16950, Loss:0.7201, Accu:0.8281
# Iter:17000, Loss:0.6277, Accu:0.8281
# save >> models/ResNeXt50_iter17000.pt
# Iter:17050, Loss:0.5736, Accu:0.8281
# Iter:17100, Loss:0.5605, Accu:0.8594
# Iter:17150, Loss:0.7074, Accu:0.7656
# Iter:17200, Loss:0.4831, Accu:0.8125
# save >> models/ResNeXt50_iter17200.pt
# Iter:17250, Loss:0.3853, Accu:0.9219
# Iter:17300, Loss:0.7140, Accu:0.7188
# Iter:17350, Loss:0.4662, Accu:0.8750
# Iter:17400, Loss:0.6991, Accu:0.8125
# save >> models/ResNeXt50_iter17400.pt
# Iter:17450, Loss:0.5352, Accu:0.8750
# Iter:17500, Loss:0.5155, Accu:0.8750
# Iter:17550, Loss:0.5254, Accu:0.8594
# Iter:17600, Loss:0.5880, Accu:0.8438
# save >> models/ResNeXt50_iter17600.pt
# Iter:17650, Loss:0.5598, Accu:0.8125
# Iter:17700, Loss:0.4442, Accu:0.9062
# Iter:17750, Loss:0.5575, Accu:0.8125
# Iter:17800, Loss:1.1636, Accu:0.6719
# save >> models/ResNeXt50_iter17800.pt
# Iter:17850, Loss:0.6284, Accu:0.7656
# Iter:17900, Loss:0.6957, Accu:0.7656
# Iter:17950, Loss:0.7287, Accu:0.6875
# Iter:18000, Loss:0.4995, Accu:0.8438
# save >> models/ResNeXt50_iter18000.pt
# Iter:18050, Loss:0.4611, Accu:0.8594
# Iter:18100, Loss:0.4040, Accu:0.8906
# Iter:18150, Loss:0.5793, Accu:0.8125
# Iter:18200, Loss:0.3973, Accu:0.8594
# save >> models/ResNeXt50_iter18200.pt
# Iter:18250, Loss:0.5640, Accu:0.8438
# Iter:18300, Loss:0.2931, Accu:0.9062
# Iter:18350, Loss:0.5352, Accu:0.8438
# Iter:18400, Loss:0.4631, Accu:0.8750
# save >> models/ResNeXt50_iter18400.pt
# Iter:18450, Loss:0.4436, Accu:0.8438
# Iter:18500, Loss:0.7808, Accu:0.7656
# Iter:18550, Loss:0.6594, Accu:0.7656
# Iter:18600, Loss:0.5743, Accu:0.7969
# save >> models/ResNeXt50_iter18600.pt
# Iter:18650, Loss:0.7150, Accu:0.7188
# Iter:18700, Loss:0.9199, Accu:0.6875
# Iter:18750, Loss:0.5207, Accu:0.8281
# Iter:18800, Loss:0.2714, Accu:0.9531
# save >> models/ResNeXt50_iter18800.pt
# Iter:18850, Loss:0.4019, Accu:0.8906
# Iter:18900, Loss:0.3768, Accu:0.8594
# Iter:18950, Loss:0.3871, Accu:0.8906
# Iter:19000, Loss:0.4349, Accu:0.8906
# save >> models/ResNeXt50_iter19000.pt
# Iter:19050, Loss:0.2477, Accu:0.9688
# Iter:19100, Loss:0.5868, Accu:0.8438
# Iter:19150, Loss:0.2964, Accu:0.9219
# Iter:19200, Loss:0.3115, Accu:0.9062
# save >> models/ResNeXt50_iter19200.pt
# Iter:19250, Loss:0.5985, Accu:0.7969
# Iter:19300, Loss:0.4821, Accu:0.8750
# Iter:19350, Loss:0.6393, Accu:0.8594
# Iter:19400, Loss:0.4572, Accu:0.8594
# save >> models/ResNeXt50_iter19400.pt
# Iter:19450, Loss:0.5695, Accu:0.8594
# Iter:19500, Loss:1.3772, Accu:0.6094
# Iter:19550, Loss:0.3062, Accu:0.9062
# Iter:19600, Loss:0.2711, Accu:0.9219
# save >> models/ResNeXt50_iter19600.pt
# Iter:19650, Loss:0.2864, Accu:0.8906
# Iter:19700, Loss:0.3244, Accu:0.9062
# Iter:19750, Loss:0.5822, Accu:0.7969
# Iter:19800, Loss:0.2014, Accu:0.9375
# save >> models/ResNeXt50_iter19800.pt
# Iter:19850, Loss:0.3993, Accu:0.9219
# Iter:19900, Loss:0.3886, Accu:0.9219
# Iter:19950, Loss:0.3672, Accu:0.8906
# Iter:20000, Loss:0.3803, Accu:0.9219
# save >> models/ResNeXt50_iter20000.pt
# final paramters were saved to >> models/ResNeXt50_final.pt
# loss was saved to >> result/ResNeXt50_loss.csv

# %% [markdown]
# # plot Loss, Accuracy

# %%
def plot_process():
    df = pd.read_csv(cfg.TRAIN.LEARNING_PROCESS_RESULT_LOSS_PATH)
    
    fig, ax = plt.subplots(figsize=(12, 4))
    ax2 = ax.twinx()
    lns1 = ax.plot(df['iteration'], df['loss'], label='loss')
    lns2 = ax2.plot(df['iteration'], df['accuracy'], color='orange', label='accuracy')

    lns = lns1 + lns2
    labs = [l.get_label() for l in lns]
    ax.legend(lns, labs, loc=0)
    ax.set_ylabel('loss')
    ax.set_xlabel('iteration')
    ax2.set_ylabel('accuracy')
    plt.grid()
    plt.show()

plot_process()

# %% [markdown]
# # Test

# %%
# test
def test():
    print('-' * 20)
    print('test function')
    print('-' * 20)
    model = ResNeXt50().to(cfg.DEVICE)
    model.load_state_dict(torch.load(cfg.TEST.MODEL_PATH, map_location=torch.device(cfg.DEVICE)))
    model.eval()

    np.random.seed(0)

    ds = torchvision.datasets.CIFAR100(root=cfg.TRAIN.DATA_PATH , train=False, download=True, transform=None)
    Xs_data = torch.tensor(ds.data, dtype=torch.float).permute(0, 3, 1, 2).to(cfg.DEVICE)
    Xs_data = Xs_data / 127.5 - 1
    ts_data = np.array(ds.targets, dtype=int)
    data_num = len(Xs_data)
    
    table = np.zeros([cfg.CLASS_NUM, cfg.CLASS_NUM])

    inds = np.arange(data_num)

    with torch.no_grad():
        for i in range(0, data_num, cfg.TEST.MINIBATCH):
            # get batch index
            mb_inds = inds[i : min(i + cfg.TEST.MINIBATCH, data_num)]
            Xs = Xs_data[mb_inds]
            ts = ts_data[mb_inds]

            # forward
            ys = model(Xs).detach().cpu().numpy()
            ys = ys.argmax(axis=1)
            
            for t, y in zip(ts, ys):
                table[t, y] += 1

            print('\r{} / {}'.format(mb_inds[-1] + 1, data_num), end='')

    accuracy = table[np.arange(cfg.CLASS_NUM), np.arange(cfg.CLASS_NUM)].sum() / table.sum()
    print('\naccuracy =', accuracy)
    print('ts / pred table')
    pprint(table)
    sns.heatmap(table)

test()
# Out:
# --------------------
# test function
# --------------------
# Files already downloaded and verified
# 10000 / 10000
# accuracy = 0.3238
# ts / pred table
# array([[53.,  2.,  2., ...,  0.,  2.,  0.],
#        [ 0., 43.,  3., ...,  1.,  0.,  0.],
#        [ 1.,  0., 24., ...,  2.,  1.,  1.],
#        ...,
#        [ 0.,  0.,  0., ..., 39.,  0.,  0.],
#        [ 1.,  0.,  5., ...,  3., 20.,  1.],
#        [ 0.,  1.,  0., ...,  1.,  1., 24.]])
